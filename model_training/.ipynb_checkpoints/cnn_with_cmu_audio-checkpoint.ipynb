# %%
import numpy as np
import IPython
from IPython.display import Audio
import torch
import torch.nn as nn
import tqdm
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
# from data import AudioData, get_dataloaders
from data import AudioData, get_dataloaders

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def display(data, fs=16000):
    IPython.display.display(Audio(data, rate=fs))

# %%
ad = AudioData(n_mfcc = 40, fs=16000)

# %%
train_dataloader, test_dataloader = get_dataloaders(ad)

# %%
print(ad.sampling_frequency)
# Out:
# 16000

# %%
for e in train_dataloader:
    X,y = e
    print('decoding x')
    decoded_X = ad.decode(X)
    print('decoded, displaying...')
    display(decoded_X)
    print('displayed')
    print(X.shape)
    print(y.shape)
    print('decoding y')
    decoded_y = ad.decode(y)
    print('decoded, dispalying')
    display(decoded_y)
    print('displayyed')
    break
# Out:
# decoding x
# decoded, displaying...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# displayed
# torch.Size([1, 525, 40])
# torch.Size([1, 525, 40])
# decoding y
# decoded, dispalying
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# displayyed

# %%
class IDK(nn.Module):
    def __init__(self, n_mfcc=40):
        super(IDK, self).__init__()
        self.l1 = torch.nn.Linear(n_mfcc, 128)
        self.l2 = torch.nn.Linear(128, n_mfcc)
        
    def forward(self, x):
        x = F.relu(self.l1(x))
        x = self.l2(x)
        return x

# %%
linear = IDK(n_mfcc=40).to(device)

# %%
class CNN(nn.Module):
    def __init__(self, n_mfcc=40):
        super(CNN, self).__init__()
        self.n_mfcc=n_mfcc
        self.k_size = 10
        self.pre_stuff = torch.nn.Sequential(
            torch.nn.Linear(self.n_mfcc, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, self.n_mfcc)
        )
        self.cnn_layers = torch.nn.Sequential(
            torch.nn.Conv2d(1, 8, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(8, 16, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(16, 32, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(32, 64, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(64, 128, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(128, 128, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(128, 64, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(64, 32, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(32, 16, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(16, 8, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(8, 4, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(4, 2, kernel_size=self.k_size, padding='same'),
            torch.nn.ReLU(),
            torch.nn.Conv2d(2, 1, kernel_size=self.k_size, padding='same'),
        )
        self.linear_layers = torch.nn.Sequential(
            torch.nn.Linear(self.n_mfcc, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, self.n_mfcc)
        )
    def forward(self, x):
        x = torch.squeeze(x)
        x = self.pre_stuff(x)
        x = torch.unsqueeze(torch.unsqueeze(x, 0), 0)
        x = self.cnn_layers(x)
        x = torch.squeeze(x)
        x = self.linear_layers(x)
        return x

# %%
cnn = CNN(n_mfcc = 80).to(device)
print(cnn)
# Out:
# CNN(
#   (pre_stuff): Sequential(
#     (0): Linear(in_features=80, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=80, bias=True)
#   )
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (3): ReLU()
#     (4): Conv2d(16, 32, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (5): ReLU()
#     (6): Conv2d(32, 64, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): Conv2d(64, 128, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (9): ReLU()
#     (10): Conv2d(128, 128, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (11): ReLU()
#     (12): Conv2d(128, 64, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (13): ReLU()
#     (14): Conv2d(64, 32, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (15): ReLU()
#     (16): Conv2d(32, 16, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (17): ReLU()
#     (18): Conv2d(16, 8, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (19): ReLU()
#     (20): Conv2d(8, 4, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (21): ReLU()
#     (22): Conv2d(4, 2, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (23): ReLU()
#     (24): Conv2d(2, 1, kernel_size=(10, 10), stride=(1, 1), padding=same)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=80, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=80, bias=True)
#   )
# )

# %%
loss = nn.MSELoss()
optimizer = optim.Adam(cnn.parameters())

EPOCHS = 2

losses = []
validation_loss = []

for i in range(EPOCHS):
    for batch in tqdm.tqdm(train_dataloader):
        cnn.zero_grad()
        batchX, batchY = batch
        batchX = torch.unsqueeze(batchX, 0) # 1 x 1 x n x 40
        batchY = torch.squeeze(batchY) # n x 40

        batchX = batchX.type(torch.FloatTensor)
        batchY = batchY.type(torch.FloatTensor)

        batchX = batchX.to(device)
        batchY = batchY.to(device)
        
        out = cnn(batchX)
        l = loss(out, batchY)
        l.backward()
        losses.append(l)
        optimizer.step()

#     with torch.no_grad():
# #         out = cnn(valX)
#         out = linear(valX)
#         L = loss(out, valY)
# #         cnn_validation_loss.append(float(L))
#         linear_validation_loss.append(float(L))
# torch.save(cnn.state_dict(), 'model')
# Out:
# 100%|██████████| 906/906 [03:20<00:00,  4.52it/s]
# 100%|██████████| 906/906 [04:52<00:00,  3.10it/s]

# %%
torch.save(cnn.state_dict(), 'modelCNNLinear')

# %%
plt.plot(losses[400:])

# %%
print(cnn)
# Out:
# CNN(
#   (pre_stuff): Sequential(
#     (0): Linear(in_features=80, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=80, bias=True)
#   )
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (3): ReLU()
#     (4): Conv2d(16, 32, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (5): ReLU()
#     (6): Conv2d(32, 64, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): Conv2d(64, 128, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (9): ReLU()
#     (10): Conv2d(128, 128, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (11): ReLU()
#     (12): Conv2d(128, 64, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (13): ReLU()
#     (14): Conv2d(64, 32, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (15): ReLU()
#     (16): Conv2d(32, 16, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (17): ReLU()
#     (18): Conv2d(16, 8, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (19): ReLU()
#     (20): Conv2d(8, 4, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (21): ReLU()
#     (22): Conv2d(4, 2, kernel_size=(10, 10), stride=(1, 1), padding=same)
#     (23): ReLU()
#     (24): Conv2d(2, 1, kernel_size=(10, 10), stride=(1, 1), padding=same)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=80, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=80, bias=True)
#   )
# )

# %%
for validation in train_dataloader:
    valX, valY = validation
    plt.figure(1)
    plt.title('X')
    plt.plot(torch.squeeze(valX))
    plt.figure(2)
    plt.title('label y')
    plt.plot(torch.squeeze(valY))
    
    valX = valX.type(torch.FloatTensor)
    valY = valY.type(torch.FloatTensor)
#     decoded = ad.decode(torch.squeeze(valX, 1).detach().numpy())
#     print('x')
#     display(decoded)
#     print('label y')
#     decoded = ad.decode(torch.squeeze(valY, 1).detach().numpy())
#     display(decoded)

    valX = torch.unsqueeze(valX, 0).to(device)
    valY = torch.unsqueeze(valY, 0).to(device)
    
    out = cnn(valX).cpu()
#     decoded = ad.decode(torch.unsqueeze(out, 0).detach().numpy())
#     print('pred y')
#     display(decoded)
    
    
    out1 = out.detach().numpy()
    
    plt.figure(3)
    plt.title('pred y')
    plt.plot(out1)
    break

# %%
print(out.shape)
print(valX.shape)
decoded = ad.decode(torch.unsqueeze(out, 0).detach().numpy())
print('pred y')
display(decoded)
out1[0]
# Out:
# torch.Size([440, 80])
# torch.Size([1, 219, 80])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19595/1986615201.py in <module>
#       1 print(out.shape)
#       2 print(valX.shape)
# ----> 3 decoded = ad.decode(torch.unsqueeze(out, 0).detach().numpy())
#       4 print('pred y')
#       5 display(decoded)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
torch.save(cnn.state_dict(), 'model')

# %%
out1[0]
# Out:
# array([ 6.1865906e+02,  9.6310326e+01,  1.9255751e+01,  3.6684582e+01,
#         6.1587296e+00,  1.0937906e+01, -2.0215192e+00, -1.4155315e+00,
#        -5.5469646e+00,  7.4684658e+00, -8.9228048e+00,  8.9033041e+00,
#        -3.6326346e+00,  1.5188480e+01, -8.8425550e+00,  3.0763836e+00,
#        -4.5181227e+00,  5.5447240e+00, -1.1228602e+01,  3.1166141e+00,
#        -6.1158376e+00,  5.5578214e-01, -4.1490660e+00,  3.4072454e+00,
#        -6.9619875e+00,  2.5427089e+00, -4.2849374e+00,  2.8158634e+00,
#        -5.1343102e+00,  6.2521780e-01, -4.6431236e+00,  8.5069972e-01,
#        -3.9909289e+00, -5.1582891e-01, -3.8753536e+00,  7.7528960e-01,
#        -3.2815192e+00,  9.5967077e-02, -3.2727995e+00, -1.6142963e+00,
#        -2.9158330e+00,  7.7099860e-01, -3.2435613e+00, -2.0620916e+00,
#        -2.6625142e-01,  4.2502818e-01, -2.1019161e+00,  1.5939043e+00,
#        -4.5708589e-02,  6.5929669e-01,  1.5463684e-01, -1.9186458e-01,
#        -5.6595081e-01,  6.2056160e-01, -2.7738469e+00,  1.5067444e+00,
#        -1.6170126e+00, -1.0455426e-01, -6.0387874e-01,  5.7285869e-01,
#         6.1279023e-01,  9.4496369e-02, -7.4970609e-01, -1.3943385e+00,
#        -6.8060708e-01, -5.6554633e-01, -2.0963709e-01, -4.7438428e-01,
#        -5.6190962e-01, -3.1605792e-01,  3.5603794e-01, -5.1408368e-01,
#         7.6628570e-03, -1.6779672e-01, -1.8973303e-01, -7.8263497e-01,
#        -6.2231451e-01, -1.9257498e-01, -4.5819551e-02,  8.7914392e-03],
#       dtype=float32)
